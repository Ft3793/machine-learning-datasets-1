# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import numpy as np
dataset = pd.read_csv('50_Startups.csv')

# %%
x = dataset.iloc[:,:-1]
y = dataset.iloc[:,4]
states = x.State.values.reshape(-1,1)
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
ohc = OneHotEncoder(handle_unknown = 'ignore')
dummies = ohc.fit_transform(states).toarray()
x.drop('State',axis = 1, inplace = True)
x = x.join(pd.DataFrame(dummies, columns=ohc.categories_[0]))

# %%
x
# Out:
#     R&D Spend  Administration  Marketing Spend  California  Florida  New York
# 0   165349.20       136897.80        471784.10         0.0      0.0       1.0
# 1   162597.70       151377.59        443898.53         1.0      0.0       0.0
# 2   153441.51       101145.55        407934.54         0.0      1.0       0.0
# 3   144372.41       118671.85        383199.62         0.0      0.0       1.0
# 4   142107.34        91391.77        366168.42         0.0      1.0       0.0
# 5   131876.90        99814.71        362861.36         0.0      0.0       1.0
# 6   134615.46       147198.87        127716.82         1.0      0.0       0.0
# 7   130298.13       145530.06        323876.68         0.0      1.0       0.0
# 8   120542.52       148718.95        311613.29         0.0      0.0       1.0
# 9   123334.88       108679.17        304981.62         1.0      0.0       0.0
# 10  101913.08       110594.11        229160.95         0.0      1.0       0.0
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 1/3,random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error
coefficient_of_dermination = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.8752655285748309

# %%
#fl = ohc.transform([['Florida']]).toarray()[0]
#a = regressor.predict([[65605,135000,205517]+fl])
mk = float(input('marketing spend: '))
rd = float(input('r and spend: '))
ad = float(input('administration spend: '))
state = input('state: ')
fl = ohc.transform([[state.capitalize()]]).toarray()[0]
values = [rd,ad,mk] + list(fl)
a = regressor.predict([values])
a
# Out:
# marketing spend: 27823
# r and spend: 237293
# administration spend: 23923
# state: florida
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([243465.13674003])

# %%
plt.scatter(range(len(y_test)),y_test,color = 'red')
plt.scatter(range(len(y_pred)),y_pred,color = 'green')
plt.show()

# %%
fl
# Out:
# array([0., 1., 0.])
